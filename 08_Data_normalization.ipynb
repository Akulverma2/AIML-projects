# %% [markdown]
# <a href="https://colab.research.google.com/github/Akulverma2/AIML-projects/blob/main/08_Data_normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
data = {
    "Age": [18, 22, 25, 30, 45, 60, 100],
    "Salary": [20000, 25000, 30000, 40000, 50000, 60000, 100000]
}
X = df

df = pd.DataFrame(data)
print("Original Data:\n", df)
plt.figure()
plt.plot(df["Age"], label="Age")
plt.plot(df["Salary"], label="Salary")
plt.title("Original Data")
plt.legend()
plt.show()
# Out:
# Original Data:
#     Age  Salary
# 0   18   20000
# 1   22   25000
# 2   25   30000
# 3   30   40000
# 4   45   50000
# 5   60   60000
# 6  100  100000

# %%
min_max = MinMaxScaler()
df_minmax = min_max.fit_transform(df)
X_train_70, X_test_30 = train_test_split(X, test_size=0.3, random_state=42)
print("\nMin-Max Scaled Data:\n", df_minmax)
df_minmax_df = pd.DataFrame(df_minmax, columns=df.columns)

plt.figure()
plt.plot(df_minmax_df["Age"], label="Age")
plt.plot(df_minmax_df["Salary"], label="Salary")
plt.title("Min-Max Scaled Data")
plt.legend()
plt.show()
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train_70)
X_test_scaled = scaler.transform(X_test_30)

X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X.columns)

plt.figure()
plt.plot(X_train_scaled_df["Age"], label="Scaled Train Age")
plt.title("Scaled Data (70-30 Split)")
plt.legend()
plt.show()
# Out:
# Min-Max Scaled Data:
#  [[0.         0.        ]
#  [0.04878049 0.0625    ]
#  [0.08536585 0.125     ]
#  [0.14634146 0.25      ]
#  [0.32926829 0.375     ]
#  [0.51219512 0.5       ]
#  [1.         1.        ]]

# %%
z_score = StandardScaler()
df_zscore = z_score.fit_transform(df)

print("\nZ-Score Scaled Data:\n", df_zscore)
df_zscore_df = pd.DataFrame(df_zscore, columns=df.columns)

plt.figure()
plt.plot(df_zscore_df["Age"], label="Age")
plt.plot(df_zscore_df["Salary"], label="Salary")
plt.title("Z-Score Scaled Data")
plt.legend()
plt.show()
# Out:
# Z-Score Scaled Data:
#  [[-0.92082828 -1.03824504]
#  [-0.77264902 -0.8418203 ]
#  [-0.66151457 -0.64539556]
#  [-0.47629049 -0.25254609]
#  [ 0.07938175  0.14030338]
#  [ 0.63505399  0.53315286]
#  [ 2.11684662  2.10455075]]

# %%
robust = RobustScaler()
df_robust = robust.fit_transform(df)

print("\nRobust Scaled Data:\n", df_robust)
df_robust_df = pd.DataFrame(df_robust, columns=df.columns)

plt.figure()
plt.plot(df_robust_df["Age"], label="Age")
plt.plot(df_robust_df["Salary"], label="Salary")
plt.title("Robust Scaled Data")
plt.legend()
plt.show()
# Out:
# Robust Scaled Data:
#  [[-0.4137931  -0.72727273]
#  [-0.27586207 -0.54545455]
#  [-0.17241379 -0.36363636]
#  [ 0.          0.        ]
#  [ 0.51724138  0.36363636]
#  [ 1.03448276  0.72727273]
#  [ 2.4137931   2.18181818]]

# %%
print("\n--- Final Comparison ---")

print("\nOriginal:\n", df)
print("\nMin-Max:\n", pd.DataFrame(df_minmax, columns=df.columns))
print("\nZ-Score:\n", pd.DataFrame(df_zscore, columns=df.columns))
print("\nRobust:\n", pd.DataFrame(df_robust, columns=df.columns))
# Out:
# --- Final Comparison ---
#
# Original:
#     Age  Salary
# 0   18   20000
# 1   22   25000
# 2   25   30000
# 3   30   40000
# 4   45   50000
# 5   60   60000
# 6  100  100000
#
# Min-Max:
#          Age  Salary
# 0  0.000000  0.0000
# 1  0.048780  0.0625
# 2  0.085366  0.1250
# 3  0.146341  0.2500
# 4  0.329268  0.3750
# 5  0.512195  0.5000
# 6  1.000000  1.0000
#
# Z-Score:
#          Age    Salary
# 0 -0.920828 -1.038245
# 1 -0.772649 -0.841820
# 2 -0.661515 -0.645396
# 3 -0.476290 -0.252546
# 4  0.079382  0.140303
# 5  0.635054  0.533153
# 6  2.116847  2.104551
#
# Robust:
#          Age    Salary
# 0 -0.413793 -0.727273
# 1 -0.275862 -0.545455
# 2 -0.172414 -0.363636
# 3  0.000000  0.000000
# 4  0.517241  0.363636
# 5  1.034483  0.727273
# 6  2.413793  2.181818
